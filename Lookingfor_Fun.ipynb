# %%
import pandas as pd
data = pd.read_csv("Clustered_Session.csv")
prod = pd.read_csv("01.Pruduct.csv") #,delimiter = '\t', thousands = ',')
# Out:
# C:\Users\User\anaconda3.7\envs\chaelin_virtenv\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
product = prod.drop(['CLNT_ID','HITS_SEQ'],axis = 1)
product[:3]
# Out:
#     SESS_ID    PD_C                         PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0   7605037  642112                           색상:워터멜론   [바비브라운]    39,000
# 1  10189797  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개       데상트    39,000
# 2   6158159  179538                         (not set)     [아베다]    39,000
#
#   PD_BUY_CT
# 0         1
# 1         2
# 2         1

# %%
product['PD_BUY_AM'] = product['PD_BUY_AM'].map(lambda x: x.replace(",", ""))

# %%
product[:3]
# Out:
#     SESS_ID    PD_C                         PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0   7605037  642112                           색상:워터멜론   [바비브라운]     39000
# 1  10189797  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개       데상트     39000
# 2   6158159  179538                         (not set)     [아베다]     39000
#
#   PD_BUY_CT
# 0         1
# 1         2
# 2         1

# %%
#buydata = data.drop(['CLNT_ID','SESS_SEQ','TOT_PAG_VIEW_CT','TOT_SESS_HR_V','CLUSTER'],axis=1)

# %%
buydata[:3]
# Out:
#    SESS_ID DVC_CTG_NM      ACTION
# 0  8641867     mobile  buy,search
# 1  6616320     mobile  buy,search
# 2  5886172     mobile  buy,search

# %%
df = pd.merge(buydata, product, left_on='SESS_ID', right_on='SESS_ID', how='left')
df[:3]
# Out:
#    SESS_ID DVC_CTG_NM      ACTION    PD_C                  PD_ADD_NM  \
# 0  8641867     mobile  buy,search  370753  색상:선택(04) 기본체크 4번 세트 / 1개
# 1  8641867     mobile  buy,search  370753      색상:선택(09) 81번 세트 / 1개
# 2  8641867     mobile  buy,search  370753      색상:선택(10) 82번 세트 / 1개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0   닥스(손수건)     20000         1
# 1   닥스(손수건)     20000         1
# 2   닥스(손수건)     20000         1

# %%
mast = pd.read_csv("06.Master.csv")   #필요없,delimiter = '\t', thousands = ',')

# %%
data = pd.merge(mast, df, left_on='PD_C', right_on='PD_C', how='left')
data.shape
# Out:
# (6158109, 12)

# %%
#ddata = data.drop(['CLAC2_NM','SESS'], axis=1)
data[:1]
# Out:
#     PD_C                                             PD_NM CLAC1_NM  \
# 0  64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
#
#     CLAC2_NM  CLAC3_NM    SESS_ID DVC_CTG_NM      ACTION  \
# 0  남성일반스포츠의류  남성스포츠티셔츠  2330751.0     mobile  buy,search
#
#                PD_ADD_NM  PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0  색상:블랙|사이즈:MD[95] / 1개  언더아머(스포츠)     49000         1

# %%
data.isnull().sum()
# Out:
# PD_C            0
# PD_NM           0
# CLAC1_NM        0
# CLAC2_NM        0
# CLAC3_NM        0
# SESS_ID       292
# DVC_CTG_NM    292
# ACTION        292
# PD_ADD_NM     292
# PD_BRA_NM     292
# PD_BUY_AM     292
# PD_BUY_CT     292
# dtype: int64

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# PD_C          0
# PD_NM         0
# CLAC1_NM      0
# CLAC2_NM      0
# CLAC3_NM      0
# SESS_ID       0
# DVC_CTG_NM    0
# ACTION        0
# PD_ADD_NM     0
# PD_BRA_NM     0
# PD_BUY_AM     0
# PD_BUY_CT     0
# dtype: int64

# %%
data.shape
# Out:
# (6157817, 12)

# %%
data.dtypes
# Out:
# PD_C            int64
# PD_NM          object
# CLAC1_NM       object
# CLAC2_NM       object
# CLAC3_NM       object
# SESS_ID       float64
# DVC_CTG_NM     object
# ACTION         object
# PD_ADD_NM      object
# PD_BRA_NM      object
# PD_BUY_AM      object
# PD_BUY_CT      object
# dtype: object

# %%
#data = data.astype({'PD_BUY_CT':'float'})
data.isnull().sum()
# Out:
# PD_C          0
# PD_NM         0
# CLAC1_NM      0
# CLAC2_NM      0
# CLAC3_NM      0
# SESS_ID       0
# DVC_CTG_NM    0
# ACTION        0
# PD_ADD_NM     0
# PD_BRA_NM     0
# PD_BUY_AM     0
# PD_BUY_CT     0
# dtype: int64

# %%
data.shape
# Out:
# (6157817, 12)

# %%
check = data['PD_C'] == 248086
data[check][40:50]
# Out:
#            PD_C                    PD_NM  CLAC1_NM CLAC2_NM CLAC3_NM  \
# 2827265  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827266  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827267  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827268  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827269  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827270  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827271  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827272  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827273  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
# 2827274  248086  [6상품권]자음 기초2종 기획세트 - 세트  화장품/뷰티케어     스킨케어   스킨케어세트
#
#            SESS_ID DVC_CTG_NM      ACTION   PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 2827265  7600508.0     mobile  buy,search  타입:세트 / 1개       설화수    120000
# ...

# %%
fun = data['PD_BUY_CT'] == 200
data[fun]
#data[fun].shape
# Out:
#            PD_C                                  PD_NM    CLAC1_NM CLAC2_NM  \
# 1389771  365082  SUNRAY ADJUST 4 BGP  386518-011 - 180       스포츠패션  유아동스포츠화
# 2559367  744058                          스누피 라인34 - 랜덤  청소/세탁/욕실용품     욕실용품
# 2633631  674046                    남성 순면 반팔런닝 1매 - 105   속옷/양말/홈웨어     남성속옷
# 2795981  211134     LED 2WAY 캠핑등 KMA14A32 - 오렌지 / FREE     아웃도어/레저       등산
# 4234096  281787                   [기프팅] 투썸이중텀블러300(레드)         상품권   모바일상품권
# 4448191  168942             페스티발 백 트레포일 (BK6730) - 000       스포츠패션    스포츠잡화
# 5164941  771600        기능성브라탑_bratop_random - 그레이 / 88        여성의류   여성의류상의
# 5164942  771600        기능성브라탑_bratop_random - 그레이 / 88        여성의류   여성의류상의
# 5164949  771600        기능성브라탑_bratop_random - 그레이 / 88        여성의류   여성의류상의
# 5164950  771600        기능성브라탑_bratop_random - 그레이 / 88        여성의류   여성의류상의
# 5164951  771600        기능성브라탑_bratop_random - 그레이 / 88        여성의류   여성의류상의
# ...

# %%
data['rank1'] = data['PD_BUY_CT'].rank(method='min', ascending=False)

# %%
data
# Out:
#            PD_C                                             PD_NM CLAC1_NM  \
# 0         64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# 1         64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# 2         64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# 3         64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# 4         64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# ...         ...                                               ...      ...
# 6158104  400197                 섀르반 올인원 수영복 (K14D5DM231) - BL/110    시즌스포츠
# 6158105  400197                 섀르반 올인원 수영복 (K14D5DM231) - BL/110    시즌스포츠
# 6158106  399225             링클플리츠주름밴딩스커트(CFHM1SK8821) - 블랙 / FREE     여성의류
# 6158107  399225             링클플리츠주름밴딩스커트(CFHM1SK8821) - 블랙 / FREE     여성의류
# 6158108  306289               클라이마쿨 쇼츠 [CX3564] - CX3564(그레이) / M    스포츠패션
#
#           CLAC2_NM   CLAC3_NM     SESS_ID DVC_CTG_NM      ACTION  \
# ...

# %%
sess = pd.read_csv("05.Session.csv")
sess[:3]
# Out:
#    CLNT_ID  SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0  5873599  8641867         9  20180509             82.0         1,890
# 1  5873599  6616320        21  20180611            105.0         1,604
# 2  5873599  5886172        40  20180624             41.0           632
#
#   DVC_CTG_NM   ZON_NM  CITY_NM
# 0     mobile  Daejeon  Daejeon
# 1     mobile    Busan    Busan
# 2     mobile  Daejeon  Daejeon

# %%
dsess = sess.drop(['SESS_DT','SESS_SEQ','TOT_SESS_HR_V','TOT_PAG_VIEW_CT'], axis=1)
dsess[:3]
# Out:
#    CLNT_ID  SESS_ID DVC_CTG_NM   ZON_NM  CITY_NM
# 0  5873599  8641867     mobile  Daejeon  Daejeon
# 1  5873599  6616320     mobile    Busan    Busan
# 2  5873599  5886172     mobile  Daejeon  Daejeon

# %%
region = sess.groupby('ZON_NM').agg({'size'})

# %%
region
# Out:
#                    CLNT_ID  SESS_ID SESS_SEQ  SESS_DT TOT_PAG_VIEW_CT  \
#                       size     size     size     size            size
# ZON_NM
# Busan               295940   295940   295940   295940          295940
# Chungcheongbuk-do    44455    44455    44455    44455           44455
# Chungcheongnam-do    78072    78072    78072    78072           78072
# Daegu               116707   116707   116707   116707          116707
# Daejeon              60442    60442    60442    60442           60442
# Gangwon-do           42701    42701    42701    42701           42701
# Gwangju              70773    70773    70773    70773           70773
# Gyeonggi-do         469954   469954   469954   469954          469954
# Gyeongsangbuk-do     91183    91183    91183    91183           91183
# Gyeongsangnam-do    128716   128716   128716   128716          128716
# Incheon             100728   100728   100728   100728          100728
# ...

# %%
product[:3]
# Out:
#     SESS_ID    PD_C                         PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0   7605037  642112                           색상:워터멜론   [바비브라운]     39000
# 1  10189797  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개       데상트     39000
# 2   6158159  179538                         (not set)     [아베다]     39000
#
#   PD_BUY_CT
# 0         1
# 1         2
# 2         1

# %%
reproduct = pd.merge(product, dsess, left_on='SESS_ID', right_on='SESS_ID', how='left')

# %%
reproduct[:3]
# Out:
#     SESS_ID    PD_C                         PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0   7605037  642112                           색상:워터멜론   [바비브라운]     39000
# 1  10189797  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개       데상트     39000
# 2   6158159  179538                         (not set)     [아베다]     39000
#
#   PD_BUY_CT  CLNT_ID DVC_CTG_NM       ZON_NM    CITY_NM
# 0         1  4139680    desktop        Seoul      Seoul
# 1         2  4140076     mobile  Gyeonggi-do  Icheon-si
# 2         1  4142395    desktop        Seoul      Seoul

# %%
reproduct = reproduct.drop(['CLNT_ID', 'PD_BUY_CT','PD_BUY_AM'], axis=1)
reproduct[:3]
# Out:
#     SESS_ID    PD_C                         PD_ADD_NM PD_BRA_NM DVC_CTG_NM  \
# 0   7605037  642112                           색상:워터멜론   [바비브라운]    desktop
# 1  10189797  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개       데상트     mobile
# 2   6158159  179538                         (not set)     [아베다]    desktop
#
#         ZON_NM    CITY_NM
# 0        Seoul      Seoul
# 1  Gyeonggi-do  Icheon-si
# 2        Seoul      Seoul

# %%
regionData = pd.merge(mast, reproduct, left_on='PD_C', right_on='PD_C', how='left')

# %%
regionData.isnull().sum()
regionData.shape
# Out:
# (6184014, 12)

# %%
#regionData.to_csv('regionData.csv')
import pandas as pd
regionData = pd.read_csv('regionData.csv')

# %%
tt = regionData['SESS_ID']==1856814
regionData[tt]
# Out:
#          Unnamed: 0    PD_C  \
# 3992676     3992676  622881
# 3992910     3992910  622881
# 3993034     3993034  622881
# 3993140     3993140  622881
# 3993211     3993211  622881
# 3993212     3993212  622881
# 3993344     3993344  622881
# 3993383     3993383  622881
# 3993539     3993539  622881
# 3993858     3993858  622881
# 3993859     3993859  622881
# 3994137     3994137  622881
# 3994286     3994286  622881
# 3994358     3994358  622881
# 3994618     3994618  622881
# 3994619     3994619  622881
# 3994620     3994620  622881
# 3994741     3994741  622881
# 3994742     3994742  622881
# 3994997     3994997  622881
# 3995146     3995146  622881
# 3995147     3995147  622881
# 3995247     3995247  622881
# 3995381     3995381  622881
# 3995382     3995382  622881
# 3995383     3995383  622881
# 3995384     3995384  622881
# 3995385     3995385  622881
# 3995386     3995386  622881
# 3995568     3995568  622881
# 3995569     3995569  622881
# 3995570     3995570  622881
# ...

# %%
seoul_filter = regionData['ZON_NM']=='Seoul'
print(regionData[seoul_filter])

seoul_data = regionData[seoul_filter]
seoul = seoul_data['PD_C']
seoul[:3]
# Out:
#          Unnamed: 0    PD_C  \
# 0                 0   64382
# 2                 2   64382
# 14               14   58280
# 23               23   58057
# 28               28  318122
# ...             ...     ...
# 6183992     6183992  703105
# 6183998     6183998  700904
# 6184007     6184007  400721
# 6184010     6184010  400197
# 6184013     6184013  306289
#
#                                                      PD_NM CLAC1_NM  \
# 0         언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# 2         언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]    스포츠패션
# 14                      선염스트라이프레이스패치원피스 JROP521D - 블루 / 85     여성의류
# 23                    배색포인트 랩스타일 원피스 (GIHOP921F) - 화이트 / F     여성의류
# 28                              H1280YRJ,K,N토트백&크로스백 - 그레이     패션잡화
# ...                                                    ...      ...
# 6183992                      여성 샌들 WAD1751GR21 - 네이비 / 225     패션잡화
# 6183998                                    가우퍼압력솥 6인용(통5중)  식기/조리기구
# ...

# %%
cnt = {}

for data in seoul:
    try: cnt[data] +=1
    except: cnt[data] = 1
cnt
# Out:
# {64382: 2,
#  58280: 1,
#  58057: 1,
#  318122: 1,
#  318011: 4,
#  317956: 5,
#  127096: 1,
#  125372: 1,
#  123395: 1,
#  122845: 2,
#  210546: 1,
#  209216: 5,
#  216029: 3,
#  214635: 1,
#  213856: 1,
#  213204: 1,
#  213185: 3,
#  266015: 2,
#  262880: 1,
#  180482: 1,
#  316577: 4,
#  312035: 1,
#  311385: 1,
#  306459: 1,
#  237368: 1,
#  236664: 6,
#  119241: 2,
#  115986: 2,
#  115913: 1,
#  115120: 1,
#  112387: 1,
#  111192: 4,
#  109817: 2,
#  109061: 2,
#  24522: 2,
#  19895: 1,
#  392764: 1,
#  392752: 2,
#  392707: 2,
#  390918: 2,
#  390776: 1,
#  389861: 1,
#  269637: 1,
#  263707: 2,
#  261189: 3,
#  260721: 1,
#  342186: 4,
#  340646: 4,
#  339896: 3,
#  337631: 3,
#  337277: 3,
#  332807: 1,
#  439396: 1,
#  439375: 1,
#  437353: 1,
#  455491: 1,
#  454332: 3,
#  450785: 2,
#  445643: 1,
#  442458: 1,
#  272178: 1,
#  271781: 1,
#  270447: 1,
#  320988: 1,
#  320123: 3,
#  311334: 1,
#  420708: 1,
#  416597: 5,
#  416457: 4,
#  255722: 1,
#  255530: 1,
# ...

# %%
cnts = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cnts[:10])
# Out:
# [(753343, 4533), (1965, 3704), (748308, 2738), (755981, 2509), (692709, 2224), (718416, 2081), (706924, 1892), (737743, 1850), (658747, 1692), (826313, 1650)]

# %%
data1 = regionData[regionData['PD_C'] == 753343 ]
data2 = regionData[regionData['PD_C'] == 1965 ]
data3 = regionData[regionData['PD_C'] == 748308 ]
data4 = regionData[regionData['PD_C'] == 755981 ]
data5 = regionData[regionData['PD_C'] == 692709 ]
data6 = regionData[regionData['PD_C'] == 718416 ]
data7 = regionData[regionData['PD_C'] == 706924 ]
data8 = regionData[regionData['PD_C'] == 737743 ]
data9 = regionData[regionData['PD_C'] == 658747 ]
data10 = regionData[regionData['PD_C'] == 826313 ]


data1 = data1[:1]
data1
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %% [markdown]
# ## 서울 제품 구매 순위 10

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C                                           PD_NM  \
# 347613       347613  753343             남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105
# 3288506     3288506    1965         홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장
# 2871969     2871969  748308                                      립스틱 - 온 홀드
# 2515580     2515580  755981      홍삼정진(進) 에브리타임 10mx30포 + 쇼핑백 증정 - 홍삼정진에브리타임
# 838092       838092  692709                       에어팟 케이스 고리형 키링 행 - 러블리 핑크
# 2852049     2852049  718416                      홍삼정 240g 롯데백화점 본점 출고 / 정관장
# 616126       616126  706924  아몬드브리즈 오리지널 190ml 24팩 - 아몬드 브리즈 오리지널 190mlx24팩
# 2918704     2918704  737743           [리필] 르 쿠션 엉크르 드 뽀 SPF23 PA++ 14g - 40
# 5789682     5789682  658747                      따뚜아쥬 꾸뛰르 타투틴트 - 15바이올렛 컨빅션
# 2115835     2115835  826313                                 풀무원 생수 2L x 6페트
#
#           CLAC1_NM   CLAC2_NM       CLAC3_NM  SESS_ID  \
# 347613   속옷/양말/홈웨어       남성속옷           남성팬티  1215019
# ...

# %% [markdown]
# ## 경기

# %%
gyeonggi_filter = regionData['ZON_NM']=='Gyeonggi-do'
print(regionData[gyeonggi_filter])

gyeonggi_data = regionData[gyeonggi_filter]
gyeonggi = gyeonggi_data['PD_C']
gyeonggi[:1]
# Out:
#          Unnamed: 0    PD_C                                             PD_NM  \
# 4                 4   64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]
# 5                 5   64382  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]
# 7                 7   61729                      88A2933253배트맨스웨트티 - 블랙 / 130
# 8                 8   61537           닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)
# 19               19   58098        V넥 고방 체크 롱 원피스 (K65-54615) - 스카이블루(SB) / F
# ...             ...     ...                                               ...
# 6183993     6183993  702567                             여성시계 AR11038 파슬코리아 직영
# 6183994     6183994  702567                             여성시계 AR11038 파슬코리아 직영
# 6183995     6183995  701213      트렌디한 꽃무늬 오프숄더 롱 원피스 (CVOW72604Q) - 아이보리 / 66
# 6184004     6184004  405748      폴란드95 구스다운 이불 싱글S.SS 1000 순면 속통 한파용 laselene
# 6184006     6184006  400890              아디다스 D2M 로고 반팔티셔츠 (BK0937) - 105(XL)
#
# ...

# %%
cnt = {}

for data in gyeonggi:
    try: cnt[data] +=1
    except: cnt[data] = 1
cnt
# Out:
# {64382: 2,
#  61729: 1,
#  61537: 1,
#  58098: 1,
#  58057: 2,
#  56306: 1,
#  317956: 1,
#  209216: 4,
#  216029: 1,
#  201823: 1,
#  255793: 1,
#  316577: 3,
#  306459: 1,
#  236664: 3,
#  112387: 1,
#  111192: 2,
#  18043: 1,
#  10841: 1,
#  392764: 2,
#  392707: 2,
#  389861: 1,
#  269117: 7,
#  342186: 4,
#  337277: 2,
#  333712: 2,
#  331633: 1,
#  440201: 1,
#  439396: 1,
#  439375: 6,
#  454332: 1,
#  450785: 2,
#  447372: 1,
#  447017: 1,
#  443453: 1,
#  320123: 6,
#  416597: 4,
#  416457: 4,
#  255722: 1,
#  252325: 1,
#  432475: 2,
#  430753: 1,
#  426961: 2,
#  219971: 4,
#  218036: 1,
#  247004: 1,
#  244918: 1,
#  243270: 1,
#  239056: 1,
#  406760: 1,
#  297774: 1,
#  293669: 1,
#  288446: 37,
#  374527: 7,
#  280793: 2,
#  280789: 1,
#  279605: 3,
#  210117: 1,
#  289211: 1,
#  286739: 1,
#  284593: 1,
#  279374: 1,
#  371266: 1,
#  370984: 1,
#  370639: 2,
#  369233: 2,
#  365623: 1,
#  363786: 6,
#  283241: 2,
#  327307: 2,
#  325272: 1,
#  321626: 1,
# ...

# %%
cntsort = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cntsort[:10])
# Out:
# [(753343, 1700), (1965, 1195), (748308, 1123), (755981, 884), (768597, 813), (706924, 770), (839528, 756), (718416, 734), (826313, 733), (658747, 705)]

# %%
data1 = regionData[regionData['PD_C'] == 753343 ]
data2 = regionData[regionData['PD_C'] == 1965 ]
data3 = regionData[regionData['PD_C'] == 748308 ]
data4 = regionData[regionData['PD_C'] == 755981 ]
data5 = regionData[regionData['PD_C'] == 768597 ]
data6 = regionData[regionData['PD_C'] == 706924 ]
data7 = regionData[regionData['PD_C'] == 839528 ]
data8 = regionData[regionData['PD_C'] == 718416]
data9 = regionData[regionData['PD_C'] == 826313 ]
data10 = regionData[regionData['PD_C'] == 658747 ]


data1 = data1[:1]
data1
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C  \
# 347613       347613  753343
# 3288506     3288506    1965
# 2871969     2871969  748308
# 2515580     2515580  755981
# 1492943     1492943  768597
# 616126       616126  706924
# 3691549     3691549  839528
# 2852049     2852049  718416
# 2115835     2115835  826313
# 5789682     5789682  658747
#
#                                                      PD_NM   CLAC1_NM  \
# 347613                 남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105  속옷/양말/홈웨어
# 3288506            홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장       건강식품
# 2871969                                         립스틱 - 온 홀드   화장품/뷰티케어
# 2515580         홍삼정진(進) 에브리타임 10mx30포 + 쇼핑백 증정 - 홍삼정진에브리타임       건강식품
# 1492943           패턴/솔리드 남성 드로즈 30종 택1 - 004)EHD5671 / 100  속옷/양말/홈웨어
# 616126      아몬드브리즈 오리지널 190ml 24팩 - 아몬드 브리즈 오리지널 190mlx24팩         음료
# 3691549  [당일배송] 2018 NEW UV플랩캡/캠핑햇 13종 택 1 - 10.캠핑햇_GRE...       패션잡화
# 2852049                         홍삼정 240g 롯데백화점 본점 출고 / 정관장       건강식품
# ...

# %% [markdown]
# ## 부산

# %%
busan_filter = regionData['ZON_NM']=='Busan'
print(regionData[busan_filter])

busan_data = regionData[busan_filter]
busan = busan_data['PD_C']
#busan[:2]
# Out:
#          Unnamed: 0    PD_C  \
# 10               10   61537
# 13               13   58820
# 18               18   58183
# 46               46  123395
# 52               52  209216
# ...             ...     ...
# 6183997     6183997  700904
# 6183999     6183999  700904
# 6184002     6184002  410356
# 6184003     6184003  409376
# 6184012     6184012  399225
#
#                                                      PD_NM   CLAC1_NM  \
# 10                 닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 13       여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
# 18          [17S/S]  울 자카드 져지 자켓 9317111001056 - 네이비 / 100       남성의류
# 46                          네이비 하와이 5부 여성 파자마 EPF8678 - 90  속옷/양말/홈웨어
# 52       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# ...                                                    ...        ...
# 6183997                                    가우퍼압력솥 6인용(통5중)    식기/조리기구
# ...

# %%
cnt = {}

for data in busan:
    try: cnt[data] +=1
    except: cnt[data] = 1
cnt
# Out:
# {61537: 1,
#  58820: 1,
#  58183: 1,
#  123395: 1,
#  209216: 2,
#  216029: 2,
#  213856: 1,
#  206498: 1,
#  202585: 1,
#  255793: 1,
#  316577: 3,
#  312035: 1,
#  306459: 1,
#  237368: 1,
#  236664: 2,
#  111192: 2,
#  24522: 1,
#  10841: 1,
#  392707: 1,
#  337631: 2,
#  333712: 1,
#  331949: 2,
#  439375: 1,
#  455494: 1,
#  455491: 1,
#  454332: 1,
#  450785: 1,
#  443453: 2,
#  320123: 3,
#  416457: 1,
#  426961: 1,
#  219971: 1,
#  241840: 2,
#  240341: 1,
#  288446: 20,
#  280793: 2,
#  279605: 1,
#  210117: 4,
#  288748: 1,
#  284593: 1,
#  232206: 2,
#  371266: 2,
#  370639: 1,
#  363786: 7,
#  283241: 2,
#  278997: 1,
#  321626: 2,
#  318034: 1,
#  317774: 6,
#  199790: 2,
#  187980: 1,
#  241778: 1,
#  304553: 1,
#  300893: 1,
#  298644: 1,
#  291077: 1,
#  213020: 1,
#  330702: 1,
#  296927: 1,
#  290649: 1,
#  288621: 1,
#  201130: 1,
#  194177: 2,
#  189844: 3,
#  188401: 1,
#  261276: 1,
#  337839: 2,
#  226742: 2,
#  187805: 1,
#  186369: 2,
#  223806: 1,
# ...

# %%
cntsortt = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cntsortt[:10])
# Out:
# [(622881, 2706), (753343, 1452), (759894, 1274), (748308, 906), (816301, 844), (1965, 796), (759267, 727), (365667, 631), (755981, 618), (768597, 558)]

# %%
data1 = regionData[regionData['PD_C'] == 622881 ]
data2 = regionData[regionData['PD_C'] == 753343 ]
data3 = regionData[regionData['PD_C'] == 759894 ]
data4 = regionData[regionData['PD_C'] == 748308 ]
data5 = regionData[regionData['PD_C'] == 816301 ]
data6 = regionData[regionData['PD_C'] == 1965 ]
data7 = regionData[regionData['PD_C'] == 759267 ]
data8 = regionData[regionData['PD_C'] == 365667 ]
data9 = regionData[regionData['PD_C'] == 755981 ]
data10 = regionData[regionData['PD_C'] == 768597 ]


data1 = data1[:1]
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C  \
# 3992676     3992676  622881
# 347613       347613  753343
# 4842152     4842152  759894
# 2871969     2871969  748308
# 5304746     5304746  816301
# 3288506     3288506    1965
# 3354410     3354410  759267
# 3539671     3539671  365667
# 2515580     2515580  755981
# 1492943     1492943  768597
#
#                                                      PD_NM   CLAC1_NM  \
# 3992676           [선미 공항패션]Taylor mini O5NBCB08_PW - BLACK       패션잡화
# 347613                 남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105  속옷/양말/홈웨어
# 4842152             테일러 MID(Taylor MID)O6FBCB22_PB - CREAM       패션잡화
# 2871969                                         립스틱 - 온 홀드   화장품/뷰티케어
# 5304746      선미 공항패션 Taylor mini O5NBCB08 - METALIC SILVER       패션잡화
# 3288506            홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장       건강식품
# 3354410                   Taylor mini O5NBCB08_PB - PEWTER       패션잡화
# 3539671  [LAP] #핫한반팔T 모음 18종택1(LAP_0416) - 14_AJGWT039_...       여성의류
# ...

# %% [markdown]
# ### 제주도!

# %%
jeju_filter = regionData['ZON_NM']=='Jeju-do'
print(regionData[jeju_filter])

jeju_data = regionData[jeju_filter]
jeju = jeju_data['PD_C']
#jeju[:1]
# Out:
#          Unnamed: 0    PD_C  \
# 75               75  209216
# 129             129  316577
# 191             191   15370
# 304             304  439375
# 317             317  454332
# ...             ...     ...
# 6183190     6183190  120662
# 6183321     6183321   48995
# 6183500     6183500  174135
# 6183511     6183511  119425
# 6183934     6183934   58550
#
#                                                      PD_NM    CLAC1_NM  \
# 75       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...       유아동의류
# 129      나이키 퓨추라 로고 반팔티 2종 택1 696707 화이트/네이비 - 나이키 퓨추라 ...       스포츠패션
# 191                Borgonovo 이탈리아 디자인 글라스 프렉티카볼 10cm 6p 세트     식기/조리기구
# 304      여성 GUESS LOSANGELES 플라워 PVC 반팔(YI2K6425) - 라이트...        남성의류
# 317                               {16D2_18S0032}런닝 - 핑크/70       유아동의류
# ...                                                    ...         ...
# 6183190                      이동식 2단 빨래바구니 - A.이동식 2단 빨래바구니  청소/세탁/욕실용품
# ...

# %%
cnt = {}

for data in jeju:
    try: cnt[data] +=1
    except: cnt[data] = 1
#cnt

# %%
cntsortt = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cntsortt[:10])
# Out:
# [(753343, 149), (736941, 62), (748308, 48), (768597, 46), (1965, 46), (427578, 41), (692709, 39), (755981, 38), (737743, 34), (409938, 34)]

# %%
data1 = regionData[regionData['PD_C'] == 753343 ]
data2 = regionData[regionData['PD_C'] == 736941 ]
data3 = regionData[regionData['PD_C'] == 748308 ]
data4 = regionData[regionData['PD_C'] == 768597 ]
data5 = regionData[regionData['PD_C'] == 1965 ]
data6 = regionData[regionData['PD_C'] == 427578 ]
data7 = regionData[regionData['PD_C'] == 692709 ]
data8 = regionData[regionData['PD_C'] ==755981]
data9 = regionData[regionData['PD_C'] == 737743 ]
data10 = regionData[regionData['PD_C'] == 409938 ]


data1 = data1[:1]
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C  \
# 347613       347613  753343
# 1340494     1340494  736941
# 2871969     2871969  748308
# 1492943     1492943  768597
# 3288506     3288506    1965
# 992717       992717  427578
# 838092       838092  692709
# 2515580     2515580  755981
# 2918704     2918704  737743
# 4871955     4871955  409938
#
#                                                      PD_NM   CLAC1_NM  \
# 347613                 남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105  속옷/양말/홈웨어
# 1340494                  래스팅 실크 UV 파운데이션 SPF20 (30ml) - 8호   화장품/뷰티케어
# 2871969                                         립스틱 - 온 홀드   화장품/뷰티케어
# 1492943           패턴/솔리드 남성 드로즈 30종 택1 - 004)EHD5671 / 100  속옷/양말/홈웨어
# 3288506            홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장       건강식품
# 992717   여성 베이직 밴딩 브라팬티 4종 택1 - 01)CDBBRM51NY/set / 80B/90  속옷/양말/홈웨어
# 838092                           에어팟 케이스 고리형 키링 행 - 러블리 핑크        모바일
# 2515580         홍삼정진(進) 에브리타임 10mx30포 + 쇼핑백 증정 - 홍삼정진에브리타임       건강식품
# ...

# %% [markdown]
# ## 경상남도

# %%
gnam_filter = regionData['ZON_NM']=='Gyeongsangnam-do'
print(regionData[gnam_filter])

gnam_data = regionData[gnam_filter]
gnam = gnam_data['PD_C']
# Out:
#          Unnamed: 0    PD_C  \
# 6                 6   62282
# 51               51  209216
# 61               61  209216
# 62               62  209216
# 98               98  209786
# ...             ...     ...
# 6183827     6183827    9449
# 6183894     6183894    3782
# 6183944     6183944  134893
# 6183981     6183981  707873
# 6184005     6184005  400890
#
#                                                      PD_NM   CLAC1_NM  \
# 6                               여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 51       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 61       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 62       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 98                                              쿠키커터클래식 6P       주방잡화
# ...                                                    ...        ...
# 6183827                             아카데미과학-다빈치 가변대포 18142A         완구
# ...

# %%
cnt = {}

for data in gnam:
    try: cnt[data] +=1
    except: cnt[data] = 1

cntsortt = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cntsortt[:10])
# Out:
# [(380539, 2440), (753343, 529), (559754, 501), (247522, 419), (748308, 355), (1965, 312), (768597, 266), (755981, 250), (554713, 230), (706924, 185)]

# %%
data1 = regionData[regionData['PD_C'] == 380539 ]
data2 = regionData[regionData['PD_C'] == 753343 ]
data3 = regionData[regionData['PD_C'] == 559754 ]
data4 = regionData[regionData['PD_C'] == 247522 ]
data5 = regionData[regionData['PD_C'] == 748308 ]
data6 = regionData[regionData['PD_C'] == 1965 ]
data7 = regionData[regionData['PD_C'] == 768597]
data8 = regionData[regionData['PD_C'] ==755981]
data9 = regionData[regionData['PD_C'] == 554713 ]
data10 = regionData[regionData['PD_C'] == 706924 ]


data1 = data1[:1]
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C  \
# 4289955     4289955  380539
# 347613       347613  753343
# 2258762     2258762  559754
# 775905       775905  247522
# 2871969     2871969  748308
# 3288506     3288506    1965
# 1492943     1492943  768597
# 2515580     2515580  755981
# 3930148     3930148  554713
# 616126       616126  706924
#
#                                                      PD_NM   CLAC1_NM  \
# 4289955         여성 브이넥 반소매 티셔츠 TFMS1KOE65D0 - N00(화이트) / M       여성의류
# 347613                 남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105  속옷/양말/홈웨어
# 2258762  여성 베이직 스트라이프 크루넥 티셔츠 TUNS1KOE23D0 - 멀티핑크(N29) / M       남성의류
# 775905   여성 슬림핏 플래그 피케 티셔츠 (TFMS1KTE60D0) - 그린(G30) / L...       여성의류
# 2871969                                         립스틱 - 온 홀드   화장품/뷰티케어
# 3288506            홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장       건강식품
# 1492943           패턴/솔리드 남성 드로즈 30종 택1 - 004)EHD5671 / 100  속옷/양말/홈웨어
# 2515580         홍삼정진(進) 에브리타임 10mx30포 + 쇼핑백 증정 - 홍삼정진에브리타임       건강식품
# ...

# %% [markdown]
# ## 대구

# %%
daegu_filter = regionData['ZON_NM']=='Daegu'
print(regionData[daegu_filter])

daegu_data = regionData[daegu_filter]
daegu = daegu_data['PD_C']
# Out:
#          Unnamed: 0    PD_C  \
# 3                 3   64382
# 20               20   58098
# 44               44  124084
# 58               58  209216
# 77               77  209216
# ...             ...     ...
# 6183908     6183908   31999
# 6183911     6183911   28292
# 6183925     6183925   62311
# 6184001     6184001  412759
# 6184009     6184009  400197
#
#                                                      PD_NM   CLAC1_NM  \
# 3         언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 20              V넥 고방 체크 롱 원피스 (K65-54615) - 스카이블루(SB) / F       여성의류
# 44                             여성백팩01H1280UBJ,UBN1FR - 그레이       패션잡화
# 58       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 77       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# ...                                                    ...        ...
# 6183908                        남성 미디 삼각팬티 3매입(L2340) - 100  속옷/양말/홈웨어
# ...

# %%
cnt = {}

for data in daegu:
    try: cnt[data] +=1
    except: cnt[data] = 1

cntsortt = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cntsortt[:10])
# Out:
# [(753343, 612), (748308, 313), (1965, 301), (755981, 237), (554713, 202), (768597, 200), (826313, 200), (405756, 190), (737743, 179), (706924, 170)]

# %%
data1 = regionData[regionData['PD_C'] == 753343 ]
data2 = regionData[regionData['PD_C'] == 748308 ]
data3 = regionData[regionData['PD_C'] == 1965 ]
data4 = regionData[regionData['PD_C'] == 755981 ]
data5 = regionData[regionData['PD_C'] == 554713 ]
data6 = regionData[regionData['PD_C'] == 768597 ]
data7 = regionData[regionData['PD_C'] == 826313]
data8 = regionData[regionData['PD_C'] ==405756]
data9 = regionData[regionData['PD_C'] == 737743]
data10 = regionData[regionData['PD_C'] == 706924 ]


data1 = data1[:1]
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C                                           PD_NM  \
# 347613       347613  753343             남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105
# 2871969     2871969  748308                                      립스틱 - 온 홀드
# 3288506     3288506    1965         홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장
# 2515580     2515580  755981      홍삼정진(進) 에브리타임 10mx30포 + 쇼핑백 증정 - 홍삼정진에브리타임
# 3930148     3930148  554713                    3D 지비츠 - 크록스악세사리 - 01.흰고래-꼬리
# 1492943     1492943  768597        패턴/솔리드 남성 드로즈 30종 택1 - 004)EHD5671 / 100
# 2115835     2115835  826313                                 풀무원 생수 2L x 6페트
# 4262827     4262827  405756                            [B]자음 기초2종 기획세트 - 셋트
# 2918704     2918704  737743           [리필] 르 쿠션 엉크르 드 뽀 SPF23 PA++ 14g - 40
# 616126       616126  706924  아몬드브리즈 오리지널 190ml 24팩 - 아몬드 브리즈 오리지널 190mlx24팩
#
#           CLAC1_NM   CLAC2_NM       CLAC3_NM   SESS_ID  \
# 347613   속옷/양말/홈웨어       남성속옷           남성팬티   1215019
# ...

# %% [markdown]
# ## 인천

# %%
incheon_filter = regionData['ZON_NM']=='Incheon'
print(regionData[incheon_filter])

incheon_data = regionData[incheon_filter]
incheon = incheon_data['PD_C']
# Out:
#          Unnamed: 0    PD_C  \
# 56               56  209216
# 57               57  209216
# 65               65  209216
# 69               69  209216
# 70               70  209216
# ...             ...     ...
# 6183813     6183813     242
# 6183831     6183831    5827
# 6183839     6183839    5827
# 6183898     6183898     859
# 6183926     6183926   62311
#
#                                                      PD_NM   CLAC1_NM  \
# 56       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 57       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 65       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 69       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# 70       코튼 혼방 폴로 피케 반팔 티셔츠( TBMS1KTS23A0-B30) - B30 / ...      유아동의류
# ...                                                    ...        ...
# 6183813                   캐릭터 양말 20종 택1 - 11.(여)버블베이비 / 블루  속옷/양말/홈웨어
# ...

# %%
cnt = {}

for data in incheon:
    try: cnt[data] +=1
    except: cnt[data] = 1

cntsortt = sorted(cnt.items(), key = lambda x:x[1], reverse=True)
print(cntsortt[:10])
# Out:
# [(753343, 499), (843603, 290), (748308, 251), (1965, 248), (755981, 194), (826313, 193), (768597, 182), (741838, 175), (839528, 171), (718416, 168)]

# %%
data1 = regionData[regionData['PD_C'] == 753343 ]
data2 = regionData[regionData['PD_C'] == 843603 ]
data3 = regionData[regionData['PD_C'] == 748308 ]
data4 = regionData[regionData['PD_C'] == 1965 ]
data5 = regionData[regionData['PD_C'] == 755981 ]
data6 = regionData[regionData['PD_C'] == 826313 ]
data7 = regionData[regionData['PD_C'] == 768597 ]
data8 = regionData[regionData['PD_C'] ==741838 ]
data9 = regionData[regionData['PD_C'] == 839528 ]
data10 = regionData[regionData['PD_C'] == 7718416 ]


data1 = data1[:1]
data2 = data2[:1]
data3 = data3[:1]
data4 = data4[:1]
data5 = data5[:1]
data6 = data6[:1]
data7 = data7[:1]
data8 = data8[:1]
data9 = data9[:1]
data10 = data10[:1]

# %%
rank = data1
rank = rank.append(data2)
rank = rank.append(data3)
rank = rank.append(data4)
rank = rank.append(data5)
rank = rank.append(data6)
rank = rank.append(data7)
rank = rank.append(data8)
rank = rank.append(data9)
rank = rank.append(data10)
rank
# Out:
#          Unnamed: 0    PD_C  \
# 347613       347613  753343
# 912772       912772  843603
# 2871969     2871969  748308
# 3288506     3288506    1965
# 2515580     2515580  755981
# 2115835     2115835  826313
# 1492943     1492943  768597
# 1356719     1356719  741838
# 3691549     3691549  839528
#
#                                                      PD_NM   CLAC1_NM  \
# 347613                 남성 드로즈 15종 택1 - 06_CCCDRM92WN / 105  속옷/양말/홈웨어
# 912772        도담이 100매 10팩 캡형 도톰한 물티슈 평량 50g - 100매 10팩 캡형    출산/육아용품
# 2871969                                         립스틱 - 온 홀드   화장품/뷰티케어
# 3288506            홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장       건강식품
# 2515580         홍삼정진(進) 에브리타임 10mx30포 + 쇼핑백 증정 - 홍삼정진에브리타임       건강식품
# 2115835                                    풀무원 생수 2L x 6페트         음료
# 1492943           패턴/솔리드 남성 드로즈 30종 택1 - 004)EHD5671 / 100  속옷/양말/홈웨어
# 1356719             치크 팝 3.5g (NEW 4가지 컬러 추가 출시) - 13 로지 팝   화장품/뷰티케어
# ...

# %% [markdown]
# ### 한번에 많이 사는 제품군 분석해보기

# %%
prod = pd.read_csv('01.Pruduct.csv')
# Out:
# C:\Users\User\anaconda3.7\envs\chaelin_virtenv\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cnt = prod['PD_BUY_CT'] == 300
prod[cnt]
# Out:
#        CLNT_ID  SESS_ID  HITS_SEQ    PD_C       PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 86090  6115621  9383518        50  771600  색상:레오파드/사이즈:66      [쿠기]     1,000
#
#       PD_BUY_CT
# 86090       300

# %%
sess = pd.read_csv('05.Session.csv')

# %%
ssun = pd.merge(sess, prod, left_on='SESS_ID', right_on = 'SESS_ID', how='left')

# %%
test = ssun['PD_C'] == 247522
ssun[test][31:40]
# Out:
#          CLNT_ID_x  SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT  \
# 3117943    2776619  4001124         3  20180725             37.0
# 3123240    2842389  1908376        45  20180829             23.0
# 3354790    4615040  7108349       400  20180604            233.0
# 3807818    1708859  7424479         2  20180529            136.0
# 3976113    4736937  2429909      1330  20180820            247.0
# 3976114    4736937  2429909      1330  20180820            247.0
# 3976115    4736937  2429909      1330  20180820            247.0
# 3976116    4736937  2429909      1330  20180820            247.0
# 3976117    4736937  2429909      1330  20180820            247.0
#
#         TOT_SESS_HR_V DVC_CTG_NM            ZON_NM   CITY_NM  CLNT_ID_y  \
# 3117943         1,168    desktop        Gangwon-do  Wonju-si    2776619
# 3123240         1,403    desktop             Seoul     Seoul    2842389
# 3354790         8,434     mobile             Seoul     Seoul    4615040
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [CLNT_ID_x, SESS_ID, SESS_SEQ, SESS_DT, TOT_PAG_VIEW_CT, TOT_SESS_HR_V, DVC_CTG_NM, ZON_NM, CITY_NM, CLNT_ID_y, HITS_SEQ, PD_C, PD_ADD_NM, PD_BRA_NM, PD_BUY_AM, PD_BUY_CT]
# Index: []
